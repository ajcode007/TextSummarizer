# %%
1+1
# Out:
# 2

# %%
dict_info = {"name":"santhosh","Age":"26"}
dict_info['name']
# Out:
# 'santhosh'

# %%
dict_info.name
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 dict_info.name
#
# AttributeError: 'dict' object has no attribute 'name'

# %%
from box import ConfigBox
dict_info = ConfigBox({"name":"santhosh","Age":"26"})

# %%
dict_info.name
# Out:
# 'santhosh'

# %%
def multiplication(x:int,y:int) -> int:
    return x*y

# %%
multiplication(2,3)
# Out:
# 6

# %%
multiplication(2,"3")
# Out:
# '33'

# %%
from ensure import ensure_annotations
@ensure_annotations
def multiplication(x:int,y:int) -> int:
    return x*y
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 from ensure import ensure_annotations
#       2 @ensure_annotations
#       3 def multiplication(x:int,y:int) -> int:
#       4     return x*y
#
# File ~\Documents\ML Projects\TextSummarizer\env\Lib\site-packages\ensure\__init__.py:4
#       1 from __future__ import absolute_import, division, print_function, unicode_literals
#       3 from ._types import NumericString, NumericByteString, IntegerString, IntegerByteString
# ----> 4 from .main import EnsureError, Ensure, Check, ensure, check, ensure_raises, ensure_raises_regex, ensure_annotations
#
# File ~\Documents\ML Projects\TextSummarizer\env\Lib\site-packages\ensure\main.py:922
#     919 check = Check()
#     921 ensure_raises = unittest_case.assertRaises
# --> 922 ensure_raises_regex = unittest_case.assertRaisesRegexp
#
# AttributeError: 'TestCase' object has no attribute 'assertRaisesRegexp'
